# %%
# !pip install scikit-learn==1.5.0

# !pip freeze > requirements.txt

# %%
# !python -V
# Out:
# Python 3.11.4

# %%
import pickle
import pandas as pd
import numpy as np
import uuid

# %%
categorical = ['PULocationID', 'DOLocationID']

def read_data(filename):
    df = pd.read_parquet(filename)
    
    df['duration'] = df.tpep_dropoff_datetime - df.tpep_pickup_datetime
    df['duration'] = df.duration.dt.total_seconds() / 60

    df = df[(df.duration >= 1) & (df.duration <= 60)].copy()

    df[categorical] = df[categorical].fillna(-1).astype('int').astype('str')
    
    return df

# %%
df = read_data('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-03.parquet')
# df = read_data('data/green_tripdata_2023-03.parquet')
# df = pd.read_parquet('data/green_tripdata_2023-03.parquet')

# %%
def apply_model(df,model_name='model.bin'):
    with open(model_name, 'rb') as f_in:
        dv, model = pickle.load(f_in)

    dicts = df[categorical].to_dict(orient='records')
    X_val = dv.transform(dicts)
    y_pred = model.predict(X_val)
    return y_pred

std_dev_predictions = np.std(apply_model(df))
std_dev_predictions
# Out:
# 6.247488852238703

# %%
year=2023
month=3
taxi_type='yellow'
df['ride_id'] = f'{year:04d}/{month:02d}_' + df.index.astype('str')
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2023-03-01 00:06:43   2023-03-01 00:16:43              1.0
# 1               2  2023-03-01 00:08:25   2023-03-01 00:39:30              2.0
# 2               1  2023-03-01 00:15:04   2023-03-01 00:29:26              0.0
# 3               1  2023-03-01 00:49:37   2023-03-01 01:01:05              1.0
# 4               2  2023-03-01 00:08:04   2023-03-01 00:11:06              1.0
# ...           ...                  ...                   ...              ...
# 3403761         2  2023-03-31 23:24:25   2023-03-31 23:40:54              NaN
# 3403762         2  2023-03-31 23:24:50   2023-04-01 00:04:12              NaN
# 3403763         2  2023-03-31 23:26:31   2023-03-31 23:49:39              NaN
# 3403764         2  2023-03-31 23:07:51   2023-03-31 23:15:56              NaN
# 3403765         2  2023-03-31 23:26:12   2023-03-31 23:31:47              NaN
#
#          trip_distance  RatecodeID store_and_fwd_flag PULocationID  \
# 0                 0.00         1.0                  N          238
# 1                12.40         1.0                  N          138
# 2                 3.30         1.0                  N          140
# 3                 2.90         1.0                  N          140
# 4                 1.23         1.0                  N           79
# ...                ...         ...                ...          ...
# 3403761           3.16         NaN               None          163
# 3403762           6.89         NaN               None          125
# 3403763           4.01         NaN               None           50
# 3403764           1.31         NaN               None          113
# 3403765           0.88         NaN               None           41
#
#         DOLocationID  payment_type  ...  extra  mta_tax  tip_amount  \
# 0                 42             2  ...    1.0      0.5        0.00
# 1                231             1  ...    6.0      0.5       12.54
# 2                186             1  ...    3.5      0.5        4.65
# 3                 43             1  ...    3.5      0.5        4.10
# 4                137             1  ...    1.0      0.5        2.44
# ...              ...           ...  ...    ...      ...         ...
# 3403761           75             0  ...    0.0      0.5        4.23
# 3403762          198             0  ...    0.0      0.5        8.98
# 3403763          224             0  ...    0.0      0.5        0.00
# 3403764          158             0  ...    0.0      0.5        3.50
# 3403765          166             0  ...    0.0      0.5        2.25
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 0                 0.0                    1.0         11.10
# 1                 0.0                    1.0         76.49
# 2                 0.0                    1.0         28.05
# 3                 0.0                    1.0         24.70
# 4                 0.0                    1.0         14.64
# ...               ...                    ...           ...
# 3403761           0.0                    1.0         20.36
# 3403762           0.0                    1.0         53.90
# 3403763           0.0                    1.0         28.02
# 3403764           0.0                    1.0         16.01
# 3403765           0.0                    1.0         17.26
#
#          congestion_surcharge  Airport_fee   duration          ride_id
# 0                         0.0         0.00  10.000000        2023/03_0
# 1                         2.5         1.25  31.083333        2023/03_1
# 2                         2.5         0.00  14.366667        2023/03_2
# 3                         2.5         0.00  11.466667        2023/03_3
# 4                         2.5         0.00   3.033333        2023/03_4
# ...                       ...          ...        ...              ...
# 3403761                   NaN          NaN  16.483333  2023/03_3403761
# 3403762                   NaN          NaN  39.366667  2023/03_3403762
# 3403763                   NaN          NaN  23.133333  2023/03_3403763
# 3403764                   NaN          NaN   8.083333  2023/03_3403764
# 3403765                   NaN          NaN   5.583333  2023/03_3403765
#
# [3316216 rows x 21 columns]

# %%
df_result=pd.DataFrame()

df_result['ride_id']=df['ride_id']
df_result['predicted_duration']=apply_model(df)

# %%
df_result.to_parquet(
    './output/yellow',
    engine='pyarrow',
    compression=None,
    index=False
)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df_result.to_parquet(
#       2     './output/yellow',
#       3     engine='pyarrow',
#       4     compression=None,
#       5     index=False
#       6 )
#
# File c:\Users\FLRG0823\Downloads\mlops-zoomcamp\mlops\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\FLRG0823\Downloads\mlops-zoomcamp\mlops\Lib\site-packages\pandas\core\frame.py:3113, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    3032 """
#    3033 Write a DataFrame to the binary parquet format.
#    3034
#    (...)
#    3109 >>> content = f.read()
#    3110 """
#    3111 from pandas.io.parquet import to_parquet
# -> 3113 return to_parquet(
#    3114     self,
#    3115     path,
#    3116     engine,
#    3117     compression=compression,
#    3118     index=index,
#    3119     partition_cols=partition_cols,
#    3120     storage_options=storage_options,
#    3121     **kwargs,
#    3122 )
#
# File c:\Users\FLRG0823\Downloads\mlops-zoomcamp\mlops\Lib\site-packages\pandas\io\parquet.py:480, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     476 impl = get_engine(engine)
#     478 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
# --> 480 impl.write(
#     481     df,
#     482     path_or_buf,
#     483     compression=compression,
#     484     index=index,
#     485     partition_cols=partition_cols,
#     486     storage_options=storage_options,
#     487     filesystem=filesystem,
#     488     **kwargs,
#     489 )
#     491 if path is None:
#     492     assert isinstance(path_or_buf, io.BytesIO)
#
# File c:\Users\FLRG0823\Downloads\mlops-zoomcamp\mlops\Lib\site-packages\pandas\io\parquet.py:228, in PyArrowImpl.write(self, df, path, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     218         self.api.parquet.write_to_dataset(
#     219             table,
#     220             path_or_handle,
#    (...)
#     224             **kwargs,
#     225         )
#     226     else:
#     227         # write to single output file
# --> 228         self.api.parquet.write_table(
#     229             table,
#     230             path_or_handle,
#     231             compression=compression,
#     232             filesystem=filesystem,
#     233             **kwargs,
#     234         )
#     235 finally:
#     236     if handles is not None:
#
# File c:\Users\FLRG0823\Downloads\mlops-zoomcamp\mlops\Lib\site-packages\pyarrow\parquet\core.py:1883, in write_table(table, where, row_group_size, version, use_dictionary, compression, write_statistics, use_deprecated_int96_timestamps, coerce_timestamps, allow_truncated_timestamps, data_page_size, flavor, filesystem, compression_level, use_byte_stream_split, column_encoding, data_page_version, use_compliant_nested_type, encryption_properties, write_batch_size, dictionary_pagesize_limit, store_schema, write_page_index, write_page_checksum, sorting_columns, **kwargs)
#    1881 use_int96 = use_deprecated_int96_timestamps
#    1882 try:
# -> 1883     with ParquetWriter(
#    1884             where, table.schema,
#    1885             filesystem=filesystem,
#    1886             version=version,
#    1887             flavor=flavor,
#    1888             use_dictionary=use_dictionary,
#    1889             write_statistics=write_statistics,
#    1890             coerce_timestamps=coerce_timestamps,
#    1891             data_page_size=data_page_size,
#    1892             allow_truncated_timestamps=allow_truncated_timestamps,
#    1893             compression=compression,
#    1894             use_deprecated_int96_timestamps=use_int96,
#    1895             compression_level=compression_level,
#    1896             use_byte_stream_split=use_byte_stream_split,
#    1897             column_encoding=column_encoding,
#    1898             data_page_version=data_page_version,
#    1899             use_compliant_nested_type=use_compliant_nested_type,
#    1900             encryption_properties=encryption_properties,
#    1901             write_batch_size=write_batch_size,
#    1902             dictionary_pagesize_limit=dictionary_pagesize_limit,
#    1903             store_schema=store_schema,
#    1904             write_page_index=write_page_index,
#    1905             write_page_checksum=write_page_checksum,
#    1906             sorting_columns=sorting_columns,
#    1907             **kwargs) as writer:
#    1908         writer.write_table(table, row_group_size=row_group_size)
#    1909 except Exception:
#
# File c:\Users\FLRG0823\Downloads\mlops-zoomcamp\mlops\Lib\site-packages\pyarrow\parquet\core.py:1004, in ParquetWriter.__init__(self, where, schema, filesystem, flavor, version, use_dictionary, compression, write_statistics, use_deprecated_int96_timestamps, compression_level, use_byte_stream_split, column_encoding, writer_engine_version, data_page_version, use_compliant_nested_type, encryption_properties, write_batch_size, dictionary_pagesize_limit, store_schema, write_page_index, write_page_checksum, sorting_columns, **options)
#     999         sink = self.file_handle = filesystem.open(path, 'wb')
#    1000     else:
#    1001         # ARROW-10480: do not auto-detect compression.  While
#    1002         # a filename like foo.parquet.gz is nonconforming, it
#    1003         # shouldn't implicitly apply compression.
# -> 1004         sink = self.file_handle = filesystem.open_output_stream(
#    1005             path, compression=None)
#    1006 else:
#    1007     sink = where
#
# File c:\Users\FLRG0823\Downloads\mlops-zoomcamp\mlops\Lib\site-packages\pyarrow\_fs.pyx:878, in pyarrow._fs.FileSystem.open_output_stream()
#
# File c:\Users\FLRG0823\Downloads\mlops-zoomcamp\mlops\Lib\site-packages\pyarrow\error.pxi:154, in pyarrow.lib.pyarrow_internal_check_status()
#
# File c:\Users\FLRG0823\Downloads\mlops-zoomcamp\mlops\Lib\site-packages\pyarrow\error.pxi:91, in pyarrow.lib.check_status()
#
# PermissionError: [WinError 5] Failed to open local file './output/yellow'. Detail: [Windows error 5] Access is denied.
